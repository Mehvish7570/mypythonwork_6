# %%
#practice day 6 session

# %%
conditional statements 
if else condition:

# %%
#accepting the user input :

# %%
name = input("please enter your name: ")

print(f"\nhello,{name}!")
# Out:
# please enter your name:  mehvish
# hello,mehvish!

# %%
message = input("tell me something and i will repeat it for you!!")

print(message)
# Out:
# tell me something and i will repeat it for you!! hello!
# hello!

# %%
pizza = input("please enter the name of pizza in the menu: ")

print(f"\nthankyou so much please wait until we prepare your order")
# Out:
# please enter the name of pizza in the menu:  cheese barbeque
# thankyou so much please wait until we prepare your order

# %%
password = input("please enter the password ")

print(f"\nthankyou so much ,for the new password mehvish we have updated it")
# Out:
# please enter the password  mehvish_pyhton1123
# thankyou so much ,for the new password mehvish we have updated it

# %%
prompt = "if you tell us who you are we can personalise the message for you"
prompt += "\nwhat is your first name:"

# %%
name = input(prompt)
# Out:
# if you tell us who you are we can personalise the message for you
# what is your first name: mehvish

# %%
prompt = "welcome to the dashboard of university of birmingham"
prompt += "\nplease enter the intrest of your study:"

# %%
university = input(prompt)
# Out:
# welcome to the dashboard of university of birmingham
# please enter the intrest of your study: health data science

# %%
# note: by default the input will be taken as strings

# %%
# passing the numerical input

# %%
age = input('how old are you?')
# Out:
# how old are you? 21

# %%
print(age)
# Out:
# 21

# %%
age
# Out:
# '21'

# %%
type(age)
# Out:
# str

# %%
age <= 18
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 age <= 18
#
# TypeError: '<=' not supported between instances of 'str' and 'int'

# %%
#here age is str instead of integer we need to convert it

# %%
age = int(age)

# %%
age >= 18
# Out:
# True

# %%
# this is called type casting of data types

# %%
# building a voting application

# %%
age = input("how old are you ")
age = int(age)

if age >= 18:
    print("you are eligible to vote")
else :
    print("try next year , you are not eligible to vote")
# Out:
# how old are you  34
# you are eligible to vote

# %%
age = input("how old are you ")
age = int(age)

if age >= 18:
    print("you are eligible to vote")
else :
    print("try next year , you are not eligible to vote")
# Out:
# how old are you  12
# try next year , you are not eligible to vote

# %%
# understanding the modulo opearator ====> %

# %%
5%3
# Out:
# 2

# %%
# modulas is nothing but remainder at the time of division

# %%
4%8
# Out:
# 4

# %%
# write  a program to define even or odd number

# %%
number = input('enter a number and i will tell its even or odd ')
number = int(number)

if number % 2 == 0:
    print("the number {number} is even")

else :
    print(f"the number {number} is odd")
# Out:
# enter a number and i will tell its even or odd  34
# the number {number} is even

# %%
# introduction to while loops

# %%
# current number is 1 but i want to print 5 number

# %%
current_number = 1

while current_number <= 5:
    print(current_number)
    current_number += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#  req :letting the user choose to quite.

# %%
prompt = "tell me something and i will repeat it back for you"
prompt += "\nEnter quite to end program"

# %%
message = " "

while message != "quite":
    message = input(prompt)
    print(message)
# Out:
# tell me something and i will repeat it back for you
# Enter quite to end program hi
# hi
# tell me something and i will repeat it back for you
# Enter quite to end program hello
# hello
# tell me something and i will repeat it back for you
# Enter quite to end program keep shining!
# keep shining!
# tell me something and i will repeat it back for you
# Enter quite to end program quite
# quite

# %%
prompt = "tell me a number which i will keep inputing until its 0"
prompt += "\nplease enter any random number"

# %%
number = ""

while number >= 0 :
     number = input(prompt)
     print(number)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 3
#       1 number = ""
# ----> 3 while number >= 0 :
#       4      number = input(prompt)
#       5      print(number)
#
# TypeError: '>=' not supported between instances of 'str' and 'int'
